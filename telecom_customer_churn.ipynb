# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
import imblearn #pip install imblearn -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import PolynomialFeatures

# %%
pd.set_option('display.max_columns', None) #显示所有列
pd.set_option('display.max_rows', None) #显示所有行
pd.set_option('max_colwidth',100)

# %%
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

df = pd.read_csv(r'C:\Users\Zhiyang\Desktop\欧冶入职文件\customer_churn\100_data.csv')  #字符串前添加r以对抗 UNICODE ERROR
display(df.head(5))
# Out:
#    Unnamed: 0 city_type credit  join_month  gat_roaming_tag  \
# 0           0      一线城市     良好          10                0
# 1           1      二线城市     良好          10                1
# 2           2      二线城市     良好           9                0
# 3           3      一线城市     较差           2                1
# 4           4      其他城市     良好          11                1
#
#    provincial_roaming_tag  two_low_user_tag  three_low_user_tag mobile_type  \
# 0                       1                 1                   0        安卓手机
# 1                       0                 0                   0        安卓手机
# 2                       1                 1                   0        安卓手机
# 3                       1                 0                   0        苹果手机
# 4                       1                 1                   0        安卓手机
#
#    TDLTE_tag  FDLTE_tag  recharge_amount  monthly_fee  grant_amount  \
# 0          0          0              100          343            35
# ...

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE

# %%
df.groupby('churn_state_at_the_end_of_month').count()
# Out:
#                                  Unnamed: 0  city_type  credit  join_month  \
# churn_state_at_the_end_of_month
# 0                                        93         93      93          93
# 1                                         7          7       7           7
#
#                                  gat_roaming_tag  provincial_roaming_tag  \
# churn_state_at_the_end_of_month
# 0                                             93                      93
# 1                                              7                       7
#
#                                  two_low_user_tag  three_low_user_tag  \
# churn_state_at_the_end_of_month
# 0                                              93                  93
# 1                                               7                   7
#
#                                  mobile_type  TDLTE_tag  FDLTE_tag  \
# churn_state_at_the_end_of_month
# 0                                         93         93         93
# ...

# %%
x, y = df.iloc[:,:-1], df.iloc[:,-1]  #分开特征x与标签y
